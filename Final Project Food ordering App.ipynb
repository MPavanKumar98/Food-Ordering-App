# %%
import random
class order_food:
    def __init__(self):
        self.login_credentials_user=[]
        self.login_credentials_admin=dict([('adminID','LL2345'),('password','l1234')])
        self.food_items=list({1:{'Item Name':'Tandoori Chicken','Quantity':'4 Pieces','Price':'INR 240','Discount':'0%','Stock':'4 Pieces'}})
        

    def admin(self):
        adminID=input("Please enter Admin ID: ")
        password=input("Please enter the password: ")
        if adminID==self.login_credentials_admin['adminID'] and password==self.login_credentials_admin['password']:
            option=int(input('\nHi Admin!!!\n1. Add New Food item\n2. Edit Food item\n3. View the list of Food items\n4. Remove a food item from menu\n0. Exit\nEnter your choice: '))
            if option==1:
                k=2
                previous_food_id=random.sample(range(k,k+1),1)
                food_id=''.join(map(str,previous_food_id))
                print(int(food_id))
                k=food_id     
                name=input('Name of Food item: ')
                quantityinput('Quantity: ')
                price=input('Price in rupees: ')
                discount=input('Discount: ')
                stock=input('Stock: ')
                new_food_item={food_id:{'Item Name':name,'Quantity':quantity,'Price':price,'Discount':discount,'Stock':stock}}
                self.food_items.append(new_food_item)
            elif option==2:
                print('Enter the fooditem Id to edit')
                x=input('Food item Id: ')
                for a in  self.food_items :
                    print(a[x])
                    break
                print('Choose the thing you want to edit')
                p=int(input('1. Item Name\n2. Quantity\n3. Price\n4. Discount\n5. Stock\n0. Exit\nEnter your choise here:  '))
                if p==1:
                    a[x]['Item Name']=input('')
                elif p==2:
                    a[x]['Quantity']=input('')
                elif p==3:
                    a[x]['Price']=input('')
                elif p==4:
                    a[x]['Discount']=input('')
                elif p==5:
                    a[x]['Stock']=input('')
                elif p==0:
                     print('Exited Successfully')
                else:
                      print("Invalid option.Please choose an option from below: ")
            elif option==3:
                print('Here are the food_items')
                for f in self.food_items:
                    print(f)
            elif option==4:
                print('Enter the fooditem Id to remove')
                y=input('Food item Id: ')
                t=self.food_items(a[y])
                del t
                print(f"Food item with Id {y} is removed successfully")
            elif option==0:
                print('Exited Successfully')
            else :
                  print("Invalid option.Please choose an option from below: ")
        
        else:
            print('Enter Valid Login Credentials')
            return
                 
    
    def user(self):    
        select = int(input("Hello!!!\nRegister yourself here for Food ordering app\n1. Register\nIf you are already registered user,please login\n2. Login\n0. Exit\nEnter your choice here: "))
        if select==1:
            print('Please enter the below details for Registration:')
            name=input('Enter your Full Name: ')
            number=input('Enter your Phone Number: ')
            email=input('Enter your E-mail Address: ')
            address=input('Enter you Address: ')
            password=input('Enter the New Password: ')
            user={'Full Name':name,'Phone Number':number,'E-mail Address':email,'Address':address,'Password':password}
            self.login_credentials_user.append(user)
        elif select==2:
            print('Please enter the login details:')
            mail=input('Enter your Registered E-mail Address: ')
            pin=input('Enter your Password: ')
            for j in self.login_credentials_user:
                if mail==j['E-mail Address'] and pin==j['Password']:
                    print('Sucessfully logged-in!')
                    choose = int(input("1. Place a new order\n2. Order History\n3. Update profile\n0. Exit\nEnter your choice here: "))
                    if choose==1:
                        print('Choose an item to order')
                        for h in self.food_items:
                            print(f" {h['Item Name']} ({h['Quantity']}) [{h['Price']}] ({h['Discount']}) [{h['Stock']}]")
                        z=int(input('Do you want to place an order\n1. Yes\n2. No\nEnter your choice here: '))
                        if z==1:
                            print(f" {h['Item Name']} ({h['Quantity']})")
                        else:
                            print('You decided not to Order')
                            
                    elif choose==2:
                        order_history=h['Item Name']  + h['Quantity']
                        print('Order History: ',order_history)
                    elif choose==3:
                        print('Choose the detail you want to edit')
                        n=int(input('1. Full Name Name\n2. Phone Number\n3. E-mail Address\n4. Address\n5. Password\n0. Exit\nEnter your choise here:  '))
                        if n==1:
                            j['Full Name']=input('')
                        elif n==2:
                            j['Phone Number']=input('')
                        elif n==3:
                            j['E-mail Address']=input('')
                        elif n==4:
                            j['Address']=input('')
                        elif n==5:
                            j['Password']=input('')
                        elif n==0:
                             print('Exited Successfully')
                        else:
                            print("Invalid option.Please choose an option from below: ")
                            
                    elif choose==0:
                         print('Exited Successfully')
                                
                    else:
                        print("Invalid choose.Please choose an option from below: ")
                else:
                    print('Enter Valid Login Credentials')
                    return
        elif select==0:
             print('Exited Successfully')
        else:
             print("Invalid select.Please choose an option from below: ")
        

food_app = order_food()

while True:
    choice = int(input("Hello!!!\n**Welcome to food ordering App**\n1. Admin\n2. User\n0. Exit\nEnter your choice here: "))
    if choice==1:
        food_app.admin()
    elif choice==2:
        food_app.user()
    elif choice==0:
        break
    else:
          print("Invalid choice.Please choose an option from below: ")
# Out:
# Hello!!!
# **Welcome to food ordering App**
# 1. Admin
# 2. User
# 0. Exit
# Enter your choice here: 2
# Hello!!!
# Register yourself here for Food ordering app
# 1. Register
# If you are already registered user,please login
# 2. Login
# 0. Exit
# Enter your choice here: 1
# Please enter the below details for Registration:
# Enter your Full Name: pavan
# Enter your Phone Number: 8179518086
# Enter your E-mail Address: pavan98147
# Enter you Address: pl
# Enter the New Password: poiuy
# Hello!!!
# **Welcome to food ordering App**
# 1. Admin
# 2. User
# 0. Exit
# Enter your choice here: 2
# Hello!!!
# Register yourself here for Food ordering app
# 1. Register
# If you are already registered user,please login
# 2. Login
# 0. Exit
# Enter your choice here: 2
# Please enter the login details:
# Enter your Registered E-mail Address: pavan98147
# Enter your Password: poiuy
# Sucessfully logged-in!
# 1. Place a new order
# 2. Order History
# 3. Update profile
# 0. Exit
# ...
